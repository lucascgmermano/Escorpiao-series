# %%
import pandas as pd
import fastparquet

# %%
df = pd.read_parquet('/home/usuario/Documentos/Escorpiao_series/Dados_processados/2_df_recodificado.parquet')

# %%
df.groupby('DT_SIN_PRI').size().reset_index(name='CASOS')
# Out:
#      DT_SIN_PRI  CASOS
# 0    1940-12-01      1
# 1    2012-06-22      1
# 2    2013-01-15      1
# 3    2013-01-20      1
# 4    2013-02-11      1
# ...         ...    ...
# 2807 2023-12-08    174
# 2808 2023-12-09    132
# 2809 2023-12-10    165
# 2810 2023-12-11    225
# 2811 2023-12-12    121
#
# [2812 rows x 2 columns]

# %%
df[df['DT_SIN_PRI']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[df['DT_SIN_PRI']]
#
# File ~/Documentos/Escorpiao_series/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documentos/Escorpiao_series/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...
