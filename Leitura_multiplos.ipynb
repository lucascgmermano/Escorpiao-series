# %% [markdown]
# ## Importar bibliotecas

# %%
import pandas as pd
from dbfread import DBF
import os

# %% [markdown]
# ## Carregar multiplos arquivos

# %%
# Diretorio contendo os arquivos .dbf
diretorio_dbf = "/home/usuario/Documentos/Escorpiao_series/Dados_brutos/"

# Selecao das colunas de interesse
colunas_selecionadas = ['DT_SIN_PRI', 'SEM_PRI','ANO_NASC', 'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 
        'CS_RACA', 'CS_ESCOL_N','ID_MN_RESI', 'ID_OCUPA_N', 'ANT_DT_ACI', 'ANT_UF', 'ANT_MUNIC_', 
        'ANT_LOCALI', 'ANT_TEMPO_','ANT_LOCA_1', 'MCLI_LOCAL', 'CLI_DOR', 'CLI_EDEMA', 
        'CLI_EQUIMO','CLI_NECROS', 'CLI_LOCAL_', 'CLI_LOCA_1', 'MCLI_SIST', 'CLI_NEURO',
        'CLI_HEMORR', 'CLI_VAGAIS', 'CLI_MIOLIT', 'CLI_RENAL', 'CLI_OUTR_2',
        'CLI_OUTR_3', 'CLI_TEMPO_', 'TP_ACIDENT', 'ANI_TIPO_1', 'ANI_SERPEN',
        'ANI_ARANHA', 'ANI_LAGART', 'TRA_CLASSI', 'CON_SOROTE', 'NU_AMPOLAS',
        'NU_AMPOL_1', 'NU_AMPOL_8', 'NU_AMPOL_6', 'NU_AMPOL_4', 'NU_AMPO_7',
        'NU_AMPO_5', 'NU_AMPOL_9', 'NU_AMPOL_3', 'COM_LOC', 'COM_SECUND',
        'COM_NECROS', 'COM_COMPOR', 'COM_DEFICT', 'COM_APUTAC', 'COM_SISTEM',
        'COM_RENAL', 'COM_EDEMA', 'COM_SEPTIC', 'COM_CHOQUE', 'DOENCA_TRA',
        'EVOLUCAO', 'DT_OBITO', 'DT_ENCERRA', 'DT_DIGITA']

# Lista para armazenar os dataframes
dataframes = []

# %%
# Iterar sobre os arquivos no diretorio

for arquivo in os.listdir(diretorio_dbf):  # Iterar sobre os arquivos no diretorio
    if arquivo.endswith(".dbf"):    # Verificar se o arquivo é um .dbf
        caminho_arquivo = os.path.join(diretorio_dbf, arquivo) # monta o caminho completo do arquivo
        tabela = DBF(filename=caminho_arquivo, load=True, encoding='latin1') # Carregar o arquivo DBF
        df = pd.DataFrame(tabela)   # Converter para DataFrame do pandas
        df = df[df['SG_UF']=='35']  # Filtrar apenas registros de SP
        df = df[colunas_selecionadas]  # Selecionar colunas de interesse
        dataframes.append(df)   # Adicionar o DataFrame à lista
# Concatenar todos os DataFrames em um unico
df_concatenado = pd.concat(dataframes, ignore_index=True) # Concatenar todos os DataFrames em um unico

# %%
# Cria pasta vazia no diretorio de destino, caso nao exista
diretorio_destino = "/home/usuario/Documentos/Escorpiao_series/Dados_processados/"
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Salvar o DataFrame concatenado em um arquivo CSV

df_concatenado.to_csv("/home/usuario/Documentos/Escorpiao_series/Dados_processados/Dados_SP_concatenados.csv", index=False)

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318832 entries, 0 to 318831
# Data columns (total 64 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   DT_SIN_PRI  318832 non-null  object
#  1   SEM_PRI     318832 non-null  object
#  2   ANO_NASC    318832 non-null  object
#  3   NU_IDADE_N  318832 non-null  int64
#  4   CS_SEXO     318832 non-null  object
#  5   CS_GESTANT  318832 non-null  object
#  6   CS_RACA     318832 non-null  object
#  7   CS_ESCOL_N  318832 non-null  object
#  8   ID_MN_RESI  318832 non-null  object
#  9   ID_OCUPA_N  318832 non-null  object
#  10  ANT_DT_ACI  318418 non-null  object
#  11  ANT_UF      318832 non-null  object
#  12  ANT_MUNIC_  318832 non-null  object
#  13  ANT_LOCALI  318832 non-null  object
#  14  ANT_TEMPO_  318832 non-null  object
#  15  ANT_LOCA_1  318832 non-null  object
#  16  MCLI_LOCAL  318832 non-null  object
#  17  CLI_DOR     318832 non-null  object
#  18  CLI_EDEMA   318832 non-null  object
#  19  CLI_EQUIMO  318832 non-null  object
#  20  CLI_NECROS  318832 non-null  object
#  21  CLI_LOCAL_  318832 non-null  object
#  22  CLI_LOCA_1  318832 non-null  object
#  23  MCLI_SIST   318832 non-null  object
#  24  CLI_NEURO   318832 non-null  object
#  25  CLI_HEMORR  318832 non-null  object
#  26  CLI_VAGAIS  318832 non-null  object
#  27  CLI_MIOLIT  318832 non-null  object
#  28  CLI_RENAL   318832 non-null  object
#  29  CLI_OUTR_2  318832 non-null  object
#  30  CLI_OUTR_3  318832 non-null  object
#  31  CLI_TEMPO_  318832 non-null  object
#  32  TP_ACIDENT  318832 non-null  object
#  33  ANI_TIPO_1  318832 non-null  object
#  34  ANI_SERPEN  318832 non-null  object
#  35  ANI_ARANHA  318832 non-null  object
#  36  ANI_LAGART  318832 non-null  object
#  37  TRA_CLASSI  318832 non-null  object
#  38  CON_SOROTE  318832 non-null  object
#  39  NU_AMPOLAS  226978 non-null  float64
#  40  NU_AMPOL_1  225000 non-null  float64
#  41  NU_AMPOL_8  225191 non-null  float64
#  42  NU_AMPOL_6  224695 non-null  float64
#  43  NU_AMPOL_4  224687 non-null  float64
#  44  NU_AMPO_7   224700 non-null  float64
#  45  NU_AMPO_5   224770 non-null  float64
#  46  NU_AMPOL_9  226638 non-null  float64
#  47  NU_AMPOL_3  224665 non-null  float64
#  48  COM_LOC     318832 non-null  object
#  49  COM_SECUND  318832 non-null  object
#  50  COM_NECROS  318832 non-null  object
#  51  COM_COMPOR  318832 non-null  object
#  52  COM_DEFICT  318832 non-null  object
#  53  COM_APUTAC  318832 non-null  object
#  54  COM_SISTEM  318832 non-null  object
#  55  COM_RENAL   318832 non-null  object
#  56  COM_EDEMA   318832 non-null  object
#  57  COM_SEPTIC  318832 non-null  object
#  58  COM_CHOQUE  318832 non-null  object
#  59  DOENCA_TRA  318832 non-null  object
#  60  EVOLUCAO    318832 non-null  object
#  61  DT_OBITO    229 non-null     object
#  62  DT_ENCERRA  315909 non-null  object
#  63  DT_DIGITA   216403 non-null  object
# dtypes: float64(9), int64(1), object(54)
# memory usage: 155.7+ MB
