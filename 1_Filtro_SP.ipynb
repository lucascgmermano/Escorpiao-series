# %% [markdown]
# # Filtragem e Unificação dos Bancos

# %% [markdown]
# ## Pacotes necessários

# %%
import pandas as pd
from dbfread import DBF

# %% [markdown]
# ## Leitura do banco

# %%
# Costela
# tabela = DBF(filename="home/costela/Documentos/Escorpiao_series/Dados_brutos/ANIMBR07.dbf", load=True, encoding='latin1')

# Notebook
tabela = DBF(filename="/home/usuario/Documentos/Escorpiao_series/Dados_brutos/ANIMBR07.dbf", load=True, encoding='latin1')

df_bruto = pd.DataFrame(tabela)

# %% [markdown]
# ## Filtro e seleção de colunas

# %%
# Filtragem para o estado de São Paulo (SP)
df_sp = df_bruto[df_bruto['SG_UF']=='35']

# Seleção das colunas de interesse
df_sp = df_sp[['DT_SIN_PRI', 'SEM_PRI','ANO_NASC', 'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
    'ID_MN_RESI', 'ID_OCUPA_N', 'ANT_DT_ACI', 'ANT_UF', 'ANT_MUNIC_', 'ANT_LOCALI', 'ANT_TEMPO_',
       'ANT_LOCA_1', 'MCLI_LOCAL', 'CLI_DOR', 'CLI_EDEMA', 'CLI_EQUIMO',
       'CLI_NECROS', 'CLI_LOCAL_', 'CLI_LOCA_1', 'MCLI_SIST', 'CLI_NEURO',
       'CLI_HEMORR', 'CLI_VAGAIS', 'CLI_MIOLIT', 'CLI_RENAL', 'CLI_OUTR_2',
       'CLI_OUTR_3', 'CLI_TEMPO_', 'TP_ACIDENT', 'ANI_TIPO_1', 'ANI_SERPEN',
       'ANI_ARANHA', 'ANI_LAGART', 'TRA_CLASSI', 'CON_SOROTE', 'NU_AMPOLAS',
       'NU_AMPOL_1', 'NU_AMPOL_8', 'NU_AMPOL_6', 'NU_AMPOL_4', 'NU_AMPO_7',
       'NU_AMPO_5', 'NU_AMPOL_9', 'NU_AMPOL_3', 'COM_LOC', 'COM_SECUND',
       'COM_NECROS', 'COM_COMPOR', 'COM_DEFICT', 'COM_APUTAC', 'COM_SISTEM',
       'COM_RENAL', 'COM_EDEMA', 'COM_SEPTIC', 'COM_CHOQUE', 'DOENCA_TRA',
       'EVOLUCAO', 'DT_OBITO', 'DT_ENCERRA', 'DT_DIGITA']]

# %% [markdown]
# ## Recodificação

# %%
# Gestante
(
    df_sp.assign(
        CS_GESTANT=lambda d: d['CS_GESTANT'].replace({
            "1": "1 semestre",
            "2": "2 semestre",
            "3": "3 semestre",
            "4": "Idade gestacional ign",
            "5": "Nao",
            "6": "Nao se apl    ica",
            "9": None
        }),
        
        CS_RACA=lambda d: d['CS_RACA'].replace({
            "1": "Branca",
            "2": "Preta",
            "3": "Amarela",
            "4": "Parda",
            "5": "Indigena",
            "9": None
        }),
        
        CS_ESCOL_N=lambda d: d['CS_ESCOL_N'].replace({
            "00": "Analfabeto",
            "01": "1 a 4 incompleto",
            "02": "4a completa",
            "03": "5 a 8 incompleto",
            "04": "Fundamental completo",
            "05": "Medio incompleto",
            "06": "Medio completo",
            "07": "Superior incompleto",
            "08": "Superior completo",
            "10": "Nao se aplica",
            "09": None
        }),
        ANT_TEMPO_=lambda d: d['ANT_TEMPO_'].replace({
            "1": "0-1h",
            "2": "1-3h",
            "3": "3-6h",
            "4": "6-12h",
            "5": "12 e 24h",
            "6": "24 e +h",
            "9": None}
    ),
        ANT_LOCA_1 = lambda d: d['ANT_LOCA_1'].replace({
            "01": "Cabeca",
            "02": "Braco",
            "03": "Ante-Braco",
            "04": "Mao",
            "05": "Dedo da Mao",
            "06": "Tronco",
            "07": "Coxa",
            "08": "Perna",
            "09": "Pe",
            "10": "Dedo do Pe",
            "99": None}),

        MCLI_LOCAL = lambda d: d['MCLI_LOCAL'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_DOR = lambda d: d['CLI_DOR'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_EDEMA = lambda d: d['CLI_EDEMA'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_EQUIMO = lambda d: d['CLI_EQUIMO'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_NECROS = lambda d: d['CLI_NECROS'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_LOCAL_ = lambda d: d['CLI_LOCAL_'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        MCLI_SIST = lambda d: d['MCLI_SIST'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_NEURO = lambda d: d['CLI_NEURO'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_HEMORR = lambda d: d['CLI_HEMORR'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_VAGAIS = lambda d: d['CLI_VAGAIS'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_MIOLIT = lambda d: d['CLI_MIOLIT'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_RENAL = lambda d: d['CLI_RENAL'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_OUTR_2 = lambda d: d['CLI_OUTR_2'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        CLI_TEMPO_ = lambda d: d['CLI_TEMPO_'].replace({
            "1": "Normal",
            "2": "Alterado",
            "9": "Nao realizado"}),

        TP_ACIDENT = lambda d: d['TP_ACIDENT'].replace({
            "1": "Serpente",
            "2": "Aranha",
            "3": "Escorpiao",
            "4": "Lagarta",
            "5": "Abelha",
            "6": "Outro",
            "9": None}),

        ANI_SERPEN = lambda d: d['ANI_SERPEN'].replace({
            "1": "Botropico",
            "2": "Crotalico",
            "3": "Elapidico",
            "4": "Laquetico",
            "5": "Serpente nao peconhenta",
            "9": None}),

        ANI_ARANHA = lambda d: d['ANI_ARANHA'].replace({
            "1": "Foneutrismo",
            "2": "Loxoscelismo",
            "3": "Latrodectismo",
            "4": "Outra aranha",
            "9": None}),

        ANI_LAGART = lambda d: d['ANI_LAGART'].replace({
            "1": "Lonomia",
            "2": "Outra lagarta",
            "9": None}),

        TRA_CLASSI=lambda d: d['TRA_CLASSI'].replace({
            "1": "Leve",
            "2": "Moderado",
            "3": "Grave",
            "9": None}),

        CON_SOROTE=lambda d: d['CON_SOROTE'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_LOC=lambda d: d['COM_LOC'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_SECUND=lambda d: d['COM_SECUND'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_NECROS=lambda d: d['COM_NECROS'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_COMPAR =lambda d: d['COM_COMPOR'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_DEFICT=lambda d: d['COM_DEFICT'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_APUTAC=lambda d: d['COM_APUTAC'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_SISTEM=lambda d: d['COM_SISTEM'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_RENAL=lambda d: d['COM_RENAL'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        COM_EDEMA=lambda d: d['COM_EDEMA'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),    

        COM_SEPTIC=lambda d: d['COM_SEPTIC'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),    
        
        COM_CHOQUE=lambda d: d['COM_CHOQUE'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        DOENCA_TRA=lambda d: d['DOENCA_TRA'].replace({
            "1": "Sim",
            "2": "Nao",
            "9": None}),

        EVOLUCAO=lambda d: d['EVOLUCAO'].replace({
            "1": "Cura",
            "2": "Obito por ap",
            "3": "Obito por outra causa",
            "9": None})
            )
)
# Out:
#         DT_SIN_PRI SEM_PRI ANO_NASC  NU_IDADE_N CS_SEXO         CS_GESTANT  \
# 50      2007-01-25  200704     1958        4048       M  Nao se apl    ica
# 103     2007-01-29  200705     1960        4046       M  Nao se apl    ica
# 104     2007-01-13  200702                 4018       M  Nao se apl    ica
# 105     2007-01-10  200702     1967        4039       F                Nao
# 106     2006-12-28  200652     1988        4018       M  Nao se apl    ica
# ...            ...     ...      ...         ...     ...                ...
# 103365  2007-12-30  200801     1951        4056       M  Nao se apl    ica
# 103366  2007-12-15  200750     1987        4020       M  Nao se apl    ica
# 103367  2007-12-06  200749     1984        4023       F                Nao
# 103368  2007-12-01  200748     1990        4017       F               None
# 103369  2007-12-22  200751     1993        4014       M  Nao se apl    ica
#
# ...
