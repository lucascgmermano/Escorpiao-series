# %% [markdown]
# # Filtragem e Unificação dos Bancos

# %% [markdown]
# ## Pacotes necessários

# %%
import pandas as pd
from dbfread import DBF

# %% [markdown]
# ## Leitura do banco

# %%
tabela = DBF("/home/usuario/Documentos/Escorpiao_series/Dados_brutos/ANIMBR07.dbf", load=True, encoding='latin1')
df_bruto = pd.DataFrame(tabela)

# %% [markdown]
# ## Filtro

# %%
df_sp = df_bruto[df_bruto['SG_UF']=='35']

# %%
df_sp.head()
# Out:
#     TP_NOT ID_AGRAVO  DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP  \
# 50       2       X29  2007-01-25  200704   2007        35     350280
# 103      2       X29  2007-01-29  200705   2007        35     354850
# 104      2       X29  2007-01-22  200704   2007        35     351660
# 105      2       X29  2007-01-25  200704   2007        35     351660
# 106      2       X29  2007-01-03  200701   2007        35     351660
#
#     ID_REGIONA  DT_SIN_PRI SEM_PRI  ... COM_SISTEM  COM_RENAL COM_EDEMA  \
# 50        1336  2007-01-25  200704  ...          2
# 103       1349  2007-01-29  200705  ...          9
# 104       1344  2007-01-13  200702  ...          2
# 105       1344  2007-01-10  200702  ...          2
# 106       1344  2006-12-28  200652  ...
#
#     COM_SEPTIC COM_CHOQUE DOENCA_TRA EVOLUCAO DT_OBITO  DT_ENCERRA   DT_DIGITA
# 50                                 1        1     None  2007-01-25  2007-01-26
# 103                                9              None  2007-02-15  2007-02-15
# 104                                1        1     None  2007-01-22  2007-01-29
# 105                                2        1     None  2007-01-25  2007-01-29
# 106                                         1     None  2007-01-03  2007-01-15
#
# [5 rows x 76 columns]
