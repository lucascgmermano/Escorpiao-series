# %% [markdown]
# # Filtragem e Unificação dos Bancos

# %% [markdown]
# ## Pacotes necessários

# %%
import pandas as pd
from dbfread import DBF

# %% [markdown]
# ## Leitura do banco

# %%
tabela = DBF("/home/usuario/Documentos/Escorpiao_series/Dados_brutos/ANIMBR07.dbf", load=True, encoding='latin1')
df_bruto = pd.DataFrame(tabela)

# %% [markdown]
# ## Filtro

# %%
df_sp = df_bruto[df_bruto['SG_UF']=='35']

# %%
df_sp['DT_SIN_PRI'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10700 entries, 50 to 103369
# Series name: DT_SIN_PRI
# Non-Null Count  Dtype
# --------------  -----
# 10700 non-null  object
# dtypes: object(1)
# memory usage: 167.2+ KB
