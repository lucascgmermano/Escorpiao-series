# %%
# Ler bibliotecas
import pandas as pd

# %%
dados = pd.read_parquet('/home/usuario/Documentos/Escorpiao_series/Dados_processados/df1_recodificado.parquet', engine='fastparquet')

# %%
dados.info
# Out:
# <bound method DataFrame.info of        DT_SIN_PRI SEM_PRI ANO_NASC NU_IDADE_N    CS_SEXO         CS_GESTANT  \
# 0      2020-01-01      01   1987,0       4032   Feminino                Nao
# 1      2020-01-01      01   2020,0       2000   Feminino  Nao se apl    ica
# 2      2020-01-01      01   1969,0       4050   Feminino                Nao
# 3      2020-01-01      01   1983,0       4036  Masculino  Nao se apl    ica
# 4      2020-01-01      01   1962,0       4057  Masculino  Nao se apl    ica
# ...           ...     ...      ...        ...        ...                ...
# 583539 2023-12-31      01   1949,0       4074   Feminino                Nao
# 583540 2023-12-31      01   2016,0       4007  Masculino  Nao se apl    ica
# 583541 2023-12-31      01   2002,0       4021   Feminino                Nao
# 583542 2023-12-31      01   2021,0       4002   Feminino  Nao se apl    ica
# 583543 2023-08-09      32   1987,0       4036  Masculino  Nao se apl    ica
#
# ...
