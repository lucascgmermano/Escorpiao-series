# %%
import pmdarima as pm

y = df_mun['TAXA_MENSAL']  # sua série mensal com índice DATA

modelo = pm.auto_arima(
    y,
    seasonal=True, m=12,
    d=1, D=1,                 # força diferença regular e sazonal
    with_intercept=True,      # permite drift (tendência)
    stepwise=True,
    trace=True,
    error_action="ignore",
    suppress_warnings=True
)

print(modelo.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pmdarima as pm
# ----> 3 y = df_mun['TAXA_MENSAL']  # sua série mensal com índice DATA
#       5 modelo = pm.auto_arima(
#       6     y,
#       7     seasonal=True, m=12,
#    (...)     13     suppress_warnings=True
#      14 )
#      16 print(modelo.summary())
#
# NameError: name 'df_mun' is not defined

# %%
diretorio = "/home/usuario/Documentos/Escorpiao_series/Dados_brutos/"

dataframes = []

# %%
tabela = DBF(filename="/home/usuario/Documentos/Escorpiao_series/Dados_brutos/ANIMBR20_preliminar.dbf", load=True, encoding='latin1')
df = pd.DataFrame(tabela)
print(repr(df.columns))
# Out:
# Index(['TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'SG_UF_NOT',
#        'ID_MUNICIP', 'ID_REGIONA', 'DT_SIN_PRI', 'SEM_PRI', 'ANO_NASC',
#        'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N', 'SG_UF',
#        'ID_MN_RESI', 'ID_RG_RESI', 'ID_PAIS', 'DT_INVEST', 'ID_OCUPA_N',
#        'ANT_DT_ACI', 'ANT_UF', 'ANT_MUNIC_', 'ANT_LOCALI', 'ANT_TEMPO_',
#        'ANT_LOCA_1', 'MCLI_LOCAL', 'CLI_DOR', 'CLI_EDEMA', 'CLI_EQUIMO',
#        'CLI_NECROS', 'CLI_LOCAL_', 'CLI_LOCA_1', 'MCLI_SIST', 'CLI_NEURO',
#        'CLI_HEMORR', 'CLI_VAGAIS', 'CLI_MIOLIT', 'CLI_RENAL', 'CLI_OUTR_2',
#        'CLI_OUTR_3', 'CLI_TEMPO_', 'TP_ACIDENT', 'ANI_TIPO_1', 'ANI_SERPEN',
#        'ANI_ARANHA', 'ANI_LAGART', 'TRA_CLASSI', 'CON_SOROTE', 'NU_AMPOLAS',
#        'NU_AMPOL_1', 'NU_AMPOL_8', 'NU_AMPOL_6', 'NU_AMPOL_4', 'NU_AMPO_7',
#        'NU_AMPO_5', 'NU_AMPOL_9', 'NU_AMPOL_3', 'COM_LOC', 'COM_SECUND',
# ...
